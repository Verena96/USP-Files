# %%
import datetime

# %%
def date_to_str(date_obj):
    
    if isinstance(date_obj,datetime.datetime):
        date_obj = date_obj.strftime('%d/%m/%Y')
    return date_obj



def particiona(lista, inicio, fim):
    i, j = inicio, fim
    pivo = lista[fim]
    while True:
        # aumentado i
        while i < j and lista[i] <= pivo: i = i + 1
        if i < j:
            lista[i], lista[j] = pivo, lista[i]
        else: break
        # diminuindo j
        while i < j and lista[j] >= pivo: j = j - 1
        if i < j: lista[i], lista[j] = lista[j], pivo
        else: break
    return i

#Método quick
from PilhaLista import PilhaLista

def Quick_Sort(lista):
    # Cria a pilha de sub-listas e inicia com lista completa
    Pilha = PilhaLista()
    Pilha.push((0, len(lista) - 1))
    # Repete até que a pilha de sub-listas esteja vazia
    while not Pilha.is_empty():
        inicio, fim = Pilha.pop()
        # Só particiona se há mais de 1 elemento
        if fim - inicio > 0:
            k = particiona(lista, inicio, fim)
            # Empilhe as sub-listas resultantes
            Pilha.push((inicio, k - 1))
            Pilha.push((k + 1, fim))

#Método da bolha

def Bolha(a):
    n = len(a)
    # i = 1, 2, ..., n - 1
    for i in range(1, n):
        # sobe com a[i] até encontrar o lugar adequado
        j = i
        while j > 0 and a[j] < a[j - 1]:
            # troca com o seu vizinho
            a[j], a[j - 1] = a[j - 1], a[j]
            # continua subindo
            j = j - 1
    
    return a

# %%
#Arquivos gerados
from random import seed, randrange
# nomes randômicos
n1 = ["Felicia", "Catulo", "Osmund", "Artmio", "Senizio", "Tilenio"]
n2 = ["Cartuxo", "Olambro", "Romulo", "Ambulo", "Atomon", "Virino"]
n3 = ["Sereno", "Soterno", "Moncoes", "Oscaran", "Topovi", "Talento"]
n4 = ["Lasmia", "Mantega", "Casas", "Lorentao", "Melkioz", "Motivio"]
nn = 6

# Gera um registro com IDENT,NOME,DATAN
# Conteúdo randômico baseado em seu NUSP
# pp = '' - gera um registro completo
# pp != '' - gera apenas uma nova datan + ident ou apenas ident

def GeraRegistro(pp):
    global n1, n2, n3, n4, nn
    # nome, datan e ident
    nome = n1[randrange(nn)] + ' ' + n2[randrange(nn)] + ' ' + n3[randrange(nn)] + ' ' + n4[randrange(nn)]
    dia = randrange(28) + 1
    mes = randrange(12) + 1
    ano = randrange(17) + 2000
    datan = f'{dia:02}' + '/' + f'{mes:02}' + '/' + f'{ano:04}'
    ident = f'{randrange(100000000000):011}'
    kr = randrange(3)
    if pp == '':
        # gera um novo registro completo
        registro = ident + ',' + nome + ',' + datan
        return registro
    elif kr == 0:
        # preserva o nome e gera datan + ident
        campos = pp.split(',')
        registro = ident + ',' + campos[1] + ',' + datan
        return registro
    elif kr == 1:
        # preserva o nome e datan e gera ident
        campos = pp.split(',')
        registro = ident + ',' + campos[1] + ',' + campos[2]
        return registro
    else:
        # preserva ident e nome e gera datan
        campos = pp.split(',')
        registro = campos[0] + ',' + campos[1] + ',' + datan
        return registro

# gera arquivo nomearq com nreg registros
def GeraArquivo(nusp, nomearq, nreg):
    # randomize
    seed(nusp)
    # quantidade de registros - gera 80% do total
    nreg80 = nreg * 80 // 100
    # tabela para guardar registros para repetição
    tab = ['' for k in range(nreg // 20)] # 5% dos registros
    # abre arquivo para gravação
    arq = open(nomearq, "w")
    # grava metade dos registros
    for k in range(nreg80):
        reg = GeraRegistro('')
        arq.write(reg + '\n')
        print(k + 1, " - ", reg)
        # guarda 5% dos registros para repetição
        if k % 20 == 0:
            # guarda em tab
            tab[k // 20] = reg
    # grava o resto dos 20% dos registros
    cont = nreg80 + 1
    for k in range(len(tab)):
        # para cada registro em tab gera 4 outros
        for j in range(4):
            reg = GeraRegistro(tab[k])
            arq.write(reg + '\n')
            print(cont, " - ", reg)
            cont += 1
    # fecha arquivo
    arq.close()
    
# Entre com seu NUSP - para randomizar
nusp = int(input("Entre com seu NUSP - para randomizar:"))
# Gera arquivo com uma certa quantidade de registros

while True:
    nome_arq = input("Entre com o nome do arquivo.txt:")
    quant_reg = int(input("Entre com a quantidade de registros:"))
    GeraArquivo(nusp, nome_arq, quant_reg)
# Out:
# Entre com seu NUSP - para randomizar:11306929
# Entre com o nome do arquivo.txt:arq1.txt
# Entre com a quantidade de registros:100
# 1  -  28968886773,Tilenio Virino Talento Casas,25/11/2014
# 2  -  64057662679,Tilenio Olambro Sereno Lasmia,28/01/2015
# 3  -  20488096983,Osmund Olambro Talento Casas,15/12/2004
# 4  -  35359079563,Catulo Atomon Moncoes Mantega,27/04/2010
# 5  -  69951838338,Catulo Romulo Soterno Lorentao,08/10/2010
# 6  -  77624234259,Senizio Olambro Soterno Lasmia,06/11/2016
# 7  -  35792318267,Catulo Cartuxo Moncoes Melkioz,16/05/2010
# 8  -  66164538519,Artmio Atomon Sereno Casas,20/08/2000
# 9  -  27465027135,Catulo Romulo Topovi Melkioz,11/08/2008
# 10  -  09357908582,Tilenio Virino Oscaran Casas,07/07/2011
# 11  -  03920343886,Artmio Ambulo Talento Lasmia,13/11/2002
# 12  -  36733811592,Artmio Virino Soterno Lorentao,25/12/2011
# 13  -  30383866471,Artmio Atomon Moncoes Mantega,05/02/2000
# 14  -  66431143149,Artmio Olambro Soterno Motivio,12/05/2015
# 15  -  84960866808,Osmund Romulo Talento Casas,18/12/2000
# 16  -  25430587697,Osmund Cartuxo Topovi Motivio,20/01/2008
# 17  -  60933901675,Catulo Atomon Moncoes Casas,07/04/2002
# 18  -  03611775063,Felicia Cartuxo Topovi Lasmia,10/12/2008
# 19  -  47791816916,Catulo Cartuxo Oscaran Casas,27/05/2013
# 20  -  73804580427,Osmund Romulo Soterno Casas,04/07/2015
# 21  -  79684069825,Osmund Ambulo Sereno Lasmia,22/10/2015
# 22  -  43165436298,Catulo Olambro Sereno Melkioz,06/07/2006
# 23  -  21036913992,Artmio Virino Sereno Melkioz,20/03/2000
# 24  -  79331981905,Senizio Virino Oscaran Motivio,16/11/2003
# 25  -  99565032655,Osmund Olambro Soterno Lorentao,19/02/2011
# 26  -  24907086373,Tilenio Cartuxo Topovi Lorentao,05/12/2011
# 27  -  30993199021,Senizio Romulo Sereno Mantega,01/04/2005
# 28  -  31006685721,Catulo Romulo Talento Lorentao,16/06/2013
# 29  -  65102531443,Senizio Atomon Sereno Mantega,16/02/2013
# 30  -  22911756409,Senizio Ambulo Topovi Lorentao,04/09/2013
# 31  -  12322072349,Artmio Ambulo Soterno Casas,09/08/2003
# 32  -  29923167732,Senizio Virino Soterno Lasmia,25/03/2013
# 33  -  90818322070,Artmio Atomon Soterno Lorentao,12/09/2015
# 34  -  87655162418,Catulo Virino Oscaran Motivio,18/07/2009
# 35  -  28560079997,Tilenio Atomon Sereno Mantega,10/11/2003
# 36  -  77552846684,Felicia Romulo Soterno Lorentao,22/05/2000
# 37  -  63161427083,Felicia Atomon Talento Mantega,07/08/2013
# 38  -  27160513266,Osmund Virino Oscaran Melkioz,11/03/2010
# 39  -  09557600583,Senizio Cartuxo Sereno Lasmia,24/05/2015
# 40  -  14706707116,Artmio Olambro Moncoes Lasmia,10/10/2007
# 41  -  04836347167,Artmio Olambro Topovi Melkioz,16/01/2014
# 42  -  71215872714,Osmund Ambulo Soterno Melkioz,09/03/2013
# 43  -  70659231136,Senizio Cartuxo Oscaran Motivio,09/07/2011
# 44  -  28495030944,Catulo Virino Moncoes Mantega,13/08/2000
# 45  -  42625903357,Felicia Olambro Soterno Lorentao,06/07/2007
# 46  -  40954612686,Catulo Ambulo Talento Motivio,22/03/2003
# 47  -  09874113662,Catulo Romulo Moncoes Melkioz,12/06/2003
# 48  -  11593915458,Senizio Atomon Soterno Mantega,10/06/2008
# 49  -  60875378854,Tilenio Ambulo Moncoes Casas,12/12/2008
# 50  -  86066164460,Osmund Olambro Soterno Casas,10/07/2015
# 51  -  97523222719,Artmio Olambro Oscaran Casas,09/10/2010
# 52  -  60684033982,Felicia Olambro Talento Lorentao,12/07/2000
# 53  -  81560356376,Senizio Ambulo Oscaran Mantega,26/12/2005
# 54  -  58758713220,Artmio Atomon Sereno Lorentao,13/11/2008
# 55  -  07838708619,Catulo Cartuxo Talento Motivio,14/03/2013
# 56  -  09330386393,Senizio Cartuxo Topovi Mantega,15/02/2009
# 57  -  13528598316,Catulo Romulo Soterno Lorentao,24/10/2006
# 58  -  28152550285,Catulo Ambulo Talento Lasmia,10/11/2002
# 59  -  45340497475,Senizio Virino Soterno Mantega,12/01/2015
# 60  -  43045915261,Osmund Romulo Talento Motivio,14/07/2015
# 61  -  12042330148,Felicia Atomon Topovi Mantega,23/06/2005
# 62  -  45825272425,Tilenio Ambulo Moncoes Casas,07/11/2006
# 63  -  11695426651,Felicia Atomon Sereno Lasmia,07/01/2002
# 64  -  06154175315,Tilenio Olambro Talento Lasmia,26/10/2015
# 65  -  97837716849,Senizio Romulo Topovi Melkioz,03/05/2003
# 66  -  46463187640,Osmund Virino Oscaran Mantega,18/08/2012
# 67  -  18143068230,Artmio Cartuxo Sereno Motivio,25/05/2002
# 68  -  97331099278,Felicia Romulo Talento Mantega,14/12/2013
# 69  -  60036753780,Osmund Cartuxo Soterno Motivio,19/06/2000
# 70  -  73642082254,Catulo Cartuxo Talento Lorentao,01/04/2005
# 71  -  32616770903,Catulo Cartuxo Sereno Motivio,01/02/2005
# 72  -  54385707105,Tilenio Virino Topovi Motivio,04/12/2016
# 73  -  11167704715,Catulo Cartuxo Sereno Lorentao,15/11/2015
# 74  -  11945576384,Senizio Atomon Sereno Motivio,03/07/2002
# 75  -  44392210830,Catulo Ambulo Topovi Casas,26/06/2016
# 76  -  24530675477,Artmio Olambro Topovi Lasmia,15/06/2013
# 77  -  17775022025,Artmio Ambulo Sereno Casas,08/07/2014
# 78  -  47436857823,Osmund Atomon Talento Mantega,26/06/2016
# 79  -  03229720877,Artmio Romulo Sereno Lasmia,19/02/2000
# 80  -  27343573646,Artmio Atomon Topovi Motivio,19/02/2015
# 81  -  30608246703,Tilenio Virino Talento Casas,25/11/2014
# 82  -  32639897913,Tilenio Virino Talento Casas,25/11/2014
# 83  -  28968886773,Tilenio Virino Talento Casas,24/07/2007
# 84  -  04881784887,Tilenio Virino Talento Casas,18/09/2013
# 85  -  92128742764,Osmund Ambulo Sereno Lasmia,22/10/2015
# 86  -  79684069825,Osmund Ambulo Sereno Lasmia,17/12/2003
# 87  -  79684069825,Osmund Ambulo Sereno Lasmia,25/01/2006
# 88  -  79684069825,Osmund Ambulo Sereno Lasmia,27/12/2005
# 89  -  45791995544,Artmio Olambro Topovi Melkioz,16/01/2014
# 90  -  04836347167,Artmio Olambro Topovi Melkioz,27/10/2003
# 91  -  04836347167,Artmio Olambro Topovi Melkioz,17/07/2013
# 92  -  04836347167,Artmio Olambro Topovi Melkioz,22/05/2006
# 93  -  09598251391,Felicia Atomon Topovi Mantega,27/09/2011
# 94  -  12042330148,Felicia Atomon Topovi Mantega,04/03/2007
# 95  -  34352210856,Felicia Atomon Topovi Mantega,23/06/2005
# 96  -  59163187557,Felicia Atomon Topovi Mantega,10/02/2000
# 97  -  58169950833,Artmio Ambulo Oscaran Motivio,07/07/2007
# 98  -  10445999374,Artmio Olambro Sereno Casas,02/07/2003
# 99  -  92827790580,Catulo Cartuxo Soterno Mantega,01/04/2014
# 100  -  62486302697,Felicia Romulo Talento Casas,27/07/2016
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-95946a8c042f> in <module>
#      79
#      80 while True:
# ---> 81     nome_arq = input("Entre com o nome do arquivo.txt:")
#      82     quant_reg = int(input("Entre com a quantidade de registros:"))
#      83     GeraArquivo(nusp, nome_arq, quant_reg)
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
#Leia e faz a divisão em TAB
TAB=[str(line).replace('\n','').split(',') for line in open('arq1.txt')]
TAB1 = TAB
TAB2 = TAB

# %%
def ClassificaSort(lista,ordem):
    
    new = []
    
    
    for l in lista:

        sortedIndex = [int(ordem[0])-1,int(ordem[1])-1,int(ordem[2])-1]
        l[-1] = datetime.datetime.strptime(l[-1], '%d/%m/%Y')
        #l[-1] = l[-1].replace('/','')
        l = [l[i] for i in sortedIndex]
        new.append(l)

        newl = sorted(new, key=lambda x: x[0])
        new2 = [x[1:] for x in newl]
        newl2 = sorted(new2, key=lambda x: x[0])
        new3 = [x[-1] for x in newl]
        newl3 = sorted(new3)



        for i,j,k in zip(range(len(newl)),range(len(newl2)),range(len(newl3))):

            #newl[i][0] = datetime.datetime.strptime(newl[i][0], '%d%m%Y').strftime('%d/%m/%Y')
            newl[i][1] = newl2[j][0]
            newl[i][2] = newl3[k]

        TAB_sorted = []

        for j in newl:

            j = [date_to_str(item) for item in j]
            TAB_sorted.append(j)
    
    return TAB_sorted

# %%
ClassificaSort(TAB2,'132')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-683ee712bf18> in <module>
# ----> 1 ClassificaSort(TAB2,'132')
#
# <ipython-input-16-ff9b887bac45> in ClassificaSort(lista, ordem)
#       7
#       8         sortedIndex = [int(ordem[0])-1,int(ordem[1])-1,int(ordem[2])-1]
# ----> 9         l[-1] = datetime.datetime.strptime(l[-1], '%d/%m/%Y')
#      10         #l[-1] = l[-1].replace('/','')
#      11         l = [l[i] for i in sortedIndex]
#
# TypeError: strptime() argument 1 must be str, not datetime.datetime

# %%
#Leia e faz a divisão em TAB
TAB=[str(line).replace('\n','').split(',') for line in open('arq1.txt')]
TAB1 = TAB 
TAB2 = TAB

# %%
def ClassificaBolha(lista,ordem):
    
    new = []
    
    
    for l in lista:

        sortedIndex = [int(ordem[0])-1,int(ordem[1])-1,int(ordem[2])-1]
        l[-1] = datetime.datetime.strptime(l[-1], '%d/%m/%Y')
        l = [l[i] for i in sortedIndex]
        new.append(l)

        l1 = [x[0] for x in new]
        l1_sorted = Bolha(l1)

        l2 = [x[1] for x in new]
        l2_sorted = Bolha(l2)

        l3 = [x[2] for x in new]
        l3_sorted = Bolha(l3)

        final = []
        for i,j,k in zip(range(len(l1_sorted)),range(len(l2_sorted)),range(len(l3_sorted))):

                    final.append([l1_sorted[i],l2_sorted[j],l3_sorted[k]])

        TAB_sorted = []

        for j in final:

            j = [date_to_str(item) for item in j]
            TAB_sorted.append(j)
    
    return TAB_sorted

# %%
ClassificaBolha(TAB,'312')
# Out:
# [['05/02/2000', '03229720877', 'Artmio Ambulo Oscaran Motivio'],
#  ['10/02/2000', '03611775063', 'Artmio Ambulo Sereno Casas'],
#  ['19/02/2000', '03920343886', 'Artmio Ambulo Soterno Casas'],
#  ['20/03/2000', '04836347167', 'Artmio Ambulo Talento Lasmia'],
#  ['22/05/2000', '04836347167', 'Artmio Atomon Moncoes Mantega'],
#  ['19/06/2000', '04836347167', 'Artmio Atomon Sereno Casas'],
#  ['12/07/2000', '04836347167', 'Artmio Atomon Sereno Lorentao'],
#  ['13/08/2000', '04881784887', 'Artmio Atomon Soterno Lorentao'],
#  ['20/08/2000', '06154175315', 'Artmio Atomon Topovi Motivio'],
#  ['18/12/2000', '07838708619', 'Artmio Cartuxo Sereno Motivio'],
#  ['07/01/2002', '09330386393', 'Artmio Olambro Moncoes Lasmia'],
#  ['07/04/2002', '09357908582', 'Artmio Olambro Oscaran Casas'],
#  ['25/05/2002', '09557600583', 'Artmio Olambro Sereno Casas'],
#  ['03/07/2002', '09598251391', 'Artmio Olambro Soterno Motivio'],
#  ['10/11/2002', '09874113662', 'Artmio Olambro Topovi Lasmia'],
#  ['13/11/2002', '10445999374', 'Artmio Olambro Topovi Melkioz'],
#  ['22/03/2003', '11167704715', 'Artmio Olambro Topovi Melkioz'],
#  ['03/05/2003', '11593915458', 'Artmio Olambro Topovi Melkioz'],
#  ['12/06/2003', '11695426651', 'Artmio Olambro Topovi Melkioz'],
#  ['02/07/2003', '11945576384', 'Artmio Olambro Topovi Melkioz'],
#  ['09/08/2003', '12042330148', 'Artmio Romulo Sereno Lasmia'],
#  ['27/10/2003', '12042330148', 'Artmio Virino Sereno Melkioz'],
#  ['10/11/2003', '12322072349', 'Artmio Virino Soterno Lorentao'],
#  ['16/11/2003', '13528598316', 'Catulo Ambulo Talento Lasmia'],
#  ['17/12/2003', '14706707116', 'Catulo Ambulo Talento Motivio'],
#  ['15/12/2004', '17775022025', 'Catulo Ambulo Topovi Casas'],
#  ['01/02/2005', '18143068230', 'Catulo Atomon Moncoes Casas'],
#  ['01/04/2005', '20488096983', 'Catulo Atomon Moncoes Mantega'],
#  ['01/04/2005', '21036913992', 'Catulo Cartuxo Moncoes Melkioz'],
#  ['23/06/2005', '22911756409', 'Catulo Cartuxo Oscaran Casas'],
#  ['23/06/2005', '24530675477', 'Catulo Cartuxo Sereno Lorentao'],
#  ['26/12/2005', '24907086373', 'Catulo Cartuxo Sereno Motivio'],
#  ['27/12/2005', '25430587697', 'Catulo Cartuxo Soterno Mantega'],
#  ['25/01/2006', '27160513266', 'Catulo Cartuxo Talento Lorentao'],
#  ['22/05/2006', '27343573646', 'Catulo Cartuxo Talento Motivio'],
#  ['06/07/2006', '27465027135', 'Catulo Olambro Sereno Melkioz'],
#  ['24/10/2006', '28152550285', 'Catulo Romulo Moncoes Melkioz'],
#  ['07/11/2006', '28495030944', 'Catulo Romulo Soterno Lorentao'],
#  ['04/03/2007', '28560079997', 'Catulo Romulo Soterno Lorentao'],
#  ['06/07/2007', '28968886773', 'Catulo Romulo Talento Lorentao'],
#  ['07/07/2007', '28968886773', 'Catulo Romulo Topovi Melkioz'],
#  ['24/07/2007', '29923167732', 'Catulo Virino Moncoes Mantega'],
#  ['10/10/2007', '30383866471', 'Catulo Virino Oscaran Motivio'],
#  ['20/01/2008', '30608246703', 'Felicia Atomon Sereno Lasmia'],
#  ['10/06/2008', '30993199021', 'Felicia Atomon Talento Mantega'],
#  ['11/08/2008', '31006685721', 'Felicia Atomon Topovi Mantega'],
#  ['13/11/2008', '32616770903', 'Felicia Atomon Topovi Mantega'],
#  ['10/12/2008', '32639897913', 'Felicia Atomon Topovi Mantega'],
#  ['12/12/2008', '34352210856', 'Felicia Atomon Topovi Mantega'],
#  ['15/02/2009', '35359079563', 'Felicia Atomon Topovi Mantega'],
#  ['18/07/2009', '35792318267', 'Felicia Cartuxo Topovi Lasmia'],
#  ['11/03/2010', '36733811592', 'Felicia Olambro Soterno Lorentao'],
#  ['27/04/2010', '40954612686', 'Felicia Olambro Talento Lorentao'],
#  ['16/05/2010', '42625903357', 'Felicia Romulo Soterno Lorentao'],
#  ['08/10/2010', '43045915261', 'Felicia Romulo Talento Casas'],
#  ['09/10/2010', '43165436298', 'Felicia Romulo Talento Mantega'],
#  ['19/02/2011', '44392210830', 'Osmund Ambulo Sereno Lasmia'],
#  ['07/07/2011', '45340497475', 'Osmund Ambulo Sereno Lasmia'],
#  ['09/07/2011', '45791995544', 'Osmund Ambulo Sereno Lasmia'],
#  ['27/09/2011', '45825272425', 'Osmund Ambulo Sereno Lasmia'],
#  ['05/12/2011', '46463187640', 'Osmund Ambulo Sereno Lasmia'],
#  ['25/12/2011', '47436857823', 'Osmund Ambulo Soterno Melkioz'],
#  ['18/08/2012', '47791816916', 'Osmund Atomon Talento Mantega'],
#  ['16/02/2013', '54385707105', 'Osmund Cartuxo Soterno Motivio'],
#  ['09/03/2013', '58169950833', 'Osmund Cartuxo Topovi Motivio'],
#  ['14/03/2013', '58758713220', 'Osmund Olambro Soterno Casas'],
#  ['25/03/2013', '59163187557', 'Osmund Olambro Soterno Lorentao'],
#  ['27/05/2013', '60036753780', 'Osmund Olambro Talento Casas'],
#  ['15/06/2013', '60684033982', 'Osmund Romulo Soterno Casas'],
#  ['16/06/2013', '60875378854', 'Osmund Romulo Talento Casas'],
#  ['17/07/2013', '60933901675', 'Osmund Romulo Talento Motivio'],
#  ['07/08/2013', '62486302697', 'Osmund Virino Oscaran Mantega'],
#  ['04/09/2013', '63161427083', 'Osmund Virino Oscaran Melkioz'],
#  ['18/09/2013', '64057662679', 'Senizio Ambulo Oscaran Mantega'],
#  ['14/12/2013', '65102531443', 'Senizio Ambulo Topovi Lorentao'],
#  ['16/01/2014', '66164538519', 'Senizio Atomon Sereno Mantega'],
#  ['16/01/2014', '66431143149', 'Senizio Atomon Sereno Motivio'],
#  ['01/04/2014', '69951838338', 'Senizio Atomon Soterno Mantega'],
#  ['08/07/2014', '70659231136', 'Senizio Cartuxo Oscaran Motivio'],
#  ['25/11/2014', '71215872714', 'Senizio Cartuxo Sereno Lasmia'],
#  ['25/11/2014', '73642082254', 'Senizio Cartuxo Topovi Mantega'],
#  ['25/11/2014', '73804580427', 'Senizio Olambro Soterno Lasmia'],
#  ['12/01/2015', '77552846684', 'Senizio Romulo Sereno Mantega'],
#  ['28/01/2015', '77624234259', 'Senizio Romulo Topovi Melkioz'],
#  ['19/02/2015', '79331981905', 'Senizio Virino Oscaran Motivio'],
#  ['12/05/2015', '79684069825', 'Senizio Virino Soterno Lasmia'],
#  ['24/05/2015', '79684069825', 'Senizio Virino Soterno Mantega'],
#  ['04/07/2015', '79684069825', 'Tilenio Ambulo Moncoes Casas'],
#  ['10/07/2015', '79684069825', 'Tilenio Ambulo Moncoes Casas'],
#  ['14/07/2015', '81560356376', 'Tilenio Atomon Sereno Mantega'],
#  ['12/09/2015', '84960866808', 'Tilenio Cartuxo Topovi Lorentao'],
#  ['22/10/2015', '86066164460', 'Tilenio Olambro Sereno Lasmia'],
#  ['22/10/2015', '87655162418', 'Tilenio Olambro Talento Lasmia'],
#  ['26/10/2015', '90818322070', 'Tilenio Virino Oscaran Casas'],
#  ['15/11/2015', '92128742764', 'Tilenio Virino Talento Casas'],
#  ['26/06/2016', '92827790580', 'Tilenio Virino Talento Casas'],
#  ['26/06/2016', '97331099278', 'Tilenio Virino Talento Casas'],
#  ['27/07/2016', '97523222719', 'Tilenio Virino Talento Casas'],
#  ['06/11/2016', '97837716849', 'Tilenio Virino Talento Casas'],
#  ['04/12/2016', '99565032655', 'Tilenio Virino Topovi Motivio']]

# %%
new = []
    
    
for l in TAB:

    #sortedIndex = [int(ordem[0])-1,int(ordem[1])-1,int(ordem[2])-1]
    sortedIndex = [0,1,2]
    l[-1] = datetime.datetime.strptime(l[-1], '%d/%m/%Y')#.strftime('%d/%m/%Y')
    #l[-1] = l[-1].replace('/','')
    l = [l[i] for i in sortedIndex]
    new.append(l)

    newl = sorted(new, key=lambda x: x[0])
    new2 = [x[1:] for x in newl]
    newl2 = sorted(new2, key=lambda x: x[0])
    new3 = [x[-1] for x in newl]
    newl3 = sorted(new3)
#newl3



   # for i,j,k in zip(range(len(newl)),range(len(newl2)),range(len(newl3))):

        #newl[i][0] = datetime.datetime.strptime(newl[i][0], '%d%m%Y').strftime('%d/%m/%Y')
    #    newl[i][1] = newl2[j][0]
     #   newl[i][2] = newl3[k]

    #TAB_sorted = []

    #for j in newl:

     #   j = [date_to_str(item) for item in j]
      #  TAB_sorted.append(j)

# %%
new = []
       
for l in TAB2:

    #sortedIndex = [int(ordem[0])-1,int(ordem[1])-1,int(ordem[2])-1]
    sortedIndex = [0,1,2]
    l[-1] = datetime.datetime.strptime(l[-1], '%d/%m/%Y')
    l = [l[i] for i in sortedIndex]
    new.append(l)
    
    l1 = [x[0] for x in new]
    l1_sorted = Bolha(l1)
    
    l2 = [x[1] for x in new]
    l2_sorted = Bolha(l2)
    
    l3 = [x[2] for x in new]
    l3_sorted = Bolha(l3)

    final = []
    for i,j,k in zip(range(len(l1_sorted)),range(len(l2_sorted)),range(len(l3_sorted))):

                final.append([l1_sorted[i],l2_sorted[j],l3_sorted[k]])

    TAB_sorted = []

    for j in final:

        j = [date_to_str(item) for item in j]
        TAB_sorted.append(j)

TAB_sorted
